# %%
import pandas as pd
from collections import Counter
from itertools import combinations

# %%
factors = pd.read_csv('factors.csv')
factors.head()
# Out:
#    order_id  product_id                                   product_name  \
# 0         1       49302                               Bulgarian Yogurt
# 1         1       11109  Organic 4% Milk Fat Whole Milk Cottage Cheese
# 2         1       10246                          Organic Celery Hearts
# 3         1       49683                                 Cucumber Kirby
# 4         1       43633           Lightly Smoked Sardines in Olive Oil
#
#    department_id department_name
# 0             16      dairy eggs
# 1             16      dairy eggs
# 2              4         produce
# 3              4         produce
# 4             15    canned goods

# %%
factors.isna().sum()
# Out:
# order_id           0
# product_id         0
# product_name       0
# department_id      0
# department_name    0
# dtype: int64

# %% [markdown]
# # Part A1: Products Report

# %%
product_id_to_name = factors.drop_duplicates(subset='product_id')[['product_id', 'product_name']].set_index('product_id')['product_name'].to_dict()
order_df = factors.groupby('order_id')['product_id'].apply(list).reset_index(name='order')

# %%
item_counts = Counter()
pair_counts = Counter()
for products in order_df['order']:
    unique_items = set(products)
    item_counts.update(unique_items)
    pair_counts.update(combinations(sorted(unique_items), 2))

# %%
num_orders = len(order_df)
results = []
for (item1, item2), count_pair in pair_counts.items():
    support = count_pair / num_orders
    confidence_1_to_2 = count_pair / item_counts[item1]
    confidence_2_to_1 = count_pair / item_counts[item2]

    if support >= 0.003:
        if confidence_1_to_2 >= 0.25:
            results.append((item1, item2, support, confidence_1_to_2))
        if confidence_2_to_1 >= 0.25:
            results.append((item2, item1, support, confidence_2_to_1))

# %%
rules_df = pd.DataFrame(results, columns=['product_id_1', 'product_id_2', 'support', 'confidence'])
rules_df['product_name_1'] = rules_df['product_id_1'].map(product_id_to_name)
rules_df['product_name_2'] = rules_df['product_id_2'].map(product_id_to_name)
rules_df = rules_df[['product_id_1', 'product_id_2', 'product_name_1', 'product_name_2', 'confidence', 'support']]
rules_df.sort_values(by='product_id_1', ascending=False)
# Out:
#     product_id_1  product_id_2  \
# 44         49683         24852
# 19         47766         24852
# 35         47626         24852
# 1          47209         13176
# 6          47144         24852
# 47         46906         24852
# 8          45066         24852
# 16         43961         24852
# 48         41950         13176
# 15         41787         24852
# 42         39928         21137
# 51         39928         13176
# 21         39877         13176
# 29         39275         21137
# 49         37646         13176
# 3          35951         13176
# 25         35221         44632
# 10         34969         24852
# 9          31717         26209
# 18         30391         13176
# 12         29487         24852
# 40         28842         26209
# 37         28204         24852
# 5          28199         24852
# 22         27966         21137
# 2          27966         13176
# 28         27521         13176
# 31         27156         13176
# 32         26209         47626
# 36         25890         24852
# 14         24184         24852
# 45         22825         13176
# 46         22825         21137
# 53         22035         21137
# 0          22035         13176
# 4          21137         13176
# 41         20114         26209
# 43         19057         13176
# 54         18465         13176
# 11         16797         24852
# 34         16759         13176
# 55         15290         24852
# 30         11777         24852
# 27         10749         13176
# 33          9839         13176
# 17          9387         24852
# 7           9076         24852
# 52          8424         24852
# 13          8277         13176
# 50          8174         13176
# 24          5876         13176
# 20          5450         24852
# 26          5077         24852
# 23          4920         24852
# 39          4605         24852
# 38          2295         15290
#
#                                     product_name_1  \
# 44                                  Cucumber Kirby
# 19                                 Organic Avocado
# 35                                     Large Lemon
# 1                             Organic Hass Avocado
# 6   Unsweetened Original Almond Breeze Almond Milk
# 47                      Grape White/Green Seedless
# 8                                 Honeycrisp Apple
# 16               Organic Peeled Whole Baby Carrots
# 48                          Organic Tomato Cluster
# 15                                  Bartlett Pears
# 42                                    Organic Kiwi
# 51                                    Organic Kiwi
# 21                      Organic Granny Smith Apple
# 29                             Organic Blueberries
# 49                             Organic Gala Apples
# 3                  Organic Unsweetened Almond Milk
# 25                            Lime Sparkling Water
# 10                                 Red Vine Tomato
# 9                                 Organic Cilantro
# 18                                Organic Cucumber
# 12                                     Roma Tomato
# 40                                Bunched Cilantro
# 37                              Organic Fuji Apple
# 5                                 Clementines, Bag
# 22                             Organic Raspberries
# 2                              Organic Raspberries
# 28                Organic Lacinato (Dinosaur) Kale
# 31                             Organic Black Beans
# 32                                           Limes
# 36               Boneless Skinless Chicken Breasts
# 14                                     Red Peppers
# 45                           Organic D'Anjou Pears
# 46                           Organic D'Anjou Pears
# 53                     Organic Whole String Cheese
# 0                      Organic Whole String Cheese
# 4                             Organic Strawberries
# 41                                Jalapeno Peppers
# 43            Organic Large Extra Fancy Fuji Apple
# 54     Organic Grade A Free Range Large Brown Eggs
# 11                                    Strawberries
# 34                            Organic Carrot Bunch
# 55                              Orange Bell Pepper
# 30                                 Red Raspberries
# 27                         Organic Red Bell Pepper
# 33                                Organic Broccoli
# 17                             Granny Smith Apples
# 7                                      Blueberries
# 52                                  Broccoli Crown
# 13                        Apple Honeycrisp Organic
# 50                            Organic Navel Orange
# 24                                   Organic Lemon
# 20                              Small Hass Avocado
# 26                          100% Whole Wheat Bread
# 23                             Seedless Red Grapes
# 39                                   Yellow Onions
# 38                              Yellow Bell Pepper
#
#                 product_name_2  confidence   support
# 44                      Banana    0.307915  0.005663
# 19                      Banana    0.299096  0.016889
# 35                      Banana    0.265274  0.016447
# 1       Bag of Organic Bananas    0.331825  0.018444
# 6                       Banana    0.298294  0.003331
# 47                      Banana    0.263261  0.003064
# 8                       Banana    0.346663  0.009382
# 16                      Banana    0.262602  0.004923
# 48      Bag of Organic Bananas    0.250197  0.004840
# 15                      Banana    0.386081  0.003552
# 42        Organic Strawberries    0.275000  0.003940
# 51      Bag of Organic Bananas    0.347872  0.004984
# 21      Bag of Organic Bananas    0.278134  0.004954
# 29        Organic Strawberries    0.255538  0.009672
# 49      Bag of Organic Bananas    0.288359  0.006173
# 3       Bag of Organic Bananas    0.281250  0.004664
# 25  Sparkling Water Grapefruit    0.256867  0.003849
# 10                      Banana    0.265891  0.004527
# 9                        Limes    0.285593  0.007675
# 18      Bag of Organic Bananas    0.274875  0.009664
# 12                      Banana    0.292883  0.004359
# 40                       Limes    0.290625  0.004253
# 37                      Banana    0.371508  0.009222
# 5                       Banana    0.315291  0.003552
# 22        Organic Strawberries    0.301118  0.012728
# 2       Bag of Organic Bananas    0.320952  0.013566
# 28      Bag of Organic Bananas    0.257808  0.003460
# 31      Bag of Organic Bananas    0.261421  0.003140
# 32                 Large Lemon    0.264379  0.012156
# 36                      Banana    0.280651  0.004466
# 14                      Banana    0.288468  0.006387
# 45      Bag of Organic Bananas    0.319070  0.004603
# 46        Organic Strawberries    0.252509  0.003643
# 53        Organic Strawberries    0.258404  0.003925
# 0       Bag of Organic Bananas    0.294531  0.004474
# 4       Bag of Organic Bananas    0.282174  0.023428
# 41                       Limes    0.288046  0.004169
# 43      Bag of Organic Bananas    0.336562  0.007416
# 54      Bag of Organic Bananas    0.251839  0.003392
# 11                      Banana    0.299969  0.014847
# 34      Bag of Organic Bananas    0.266935  0.003544
# 55                      Banana    0.261266  0.003712
# 30                      Banana    0.294039  0.003346
# 27      Bag of Organic Bananas    0.262850  0.004794
# 33      Bag of Organic Bananas    0.317604  0.004001
# 17                      Banana    0.314721  0.003308
# 7                       Banana    0.308222  0.005457
# 52                      Banana    0.315484  0.007050
# 13      Bag of Organic Bananas    0.305062  0.005236
# 50      Bag of Organic Bananas    0.366162  0.005526
# 24      Bag of Organic Bananas    0.304422  0.008132
# 20                      Banana    0.278762  0.006593
# 26                      Banana    0.273281  0.004786
# 23                      Banana    0.286277  0.008856
# 39                      Banana    0.284689  0.008163
# 38          Orange Bell Pepper    0.339623  0.003018

# %%
rules_df.to_csv('products_report.csv', index=False)

# %% [markdown]
# # Part A2: Departments Report

# %%
dept_id_to_name = factors.drop_duplicates(subset='department_id')[['department_id', 'department_name']].set_index('department_id')['department_name'].to_dict()
order_dept_df = factors.groupby('order_id')['department_id'].apply(lambda x: list(set(x))).reset_index(name='departments')
num_orders = len(order_dept_df)
dept_counts = Counter()
dept_pair_counts = Counter()
for depts in order_dept_df['departments']:
    dept_counts.update(depts)
    dept_pair_counts.update(combinations(sorted(depts), 2))

# %%
dept_rules = []
for (dept1, dept2), count_pair in dept_pair_counts.items():
    support = count_pair / num_orders
    confidence_1_to_2 = count_pair / dept_counts[dept1]
    confidence_2_to_1 = count_pair / dept_counts[dept2]

    if support >= 0.003:
        if confidence_1_to_2 >= 0.25:
            dept_rules.append((dept1, dept2, support, confidence_1_to_2))
        if confidence_2_to_1 >= 0.25:
            dept_rules.append((dept2, dept1, support, confidence_2_to_1))

# %%
dept_rules_df = pd.DataFrame(dept_rules, columns=['department_id_1', 'department_id_2', 'support', 'confidence'])
dept_rules_df['department_name_1'] = dept_rules_df['department_id_1'].map(dept_id_to_name)
dept_rules_df['department_name_2'] = dept_rules_df['department_id_2'].map(dept_id_to_name)
dept_rules_df = dept_rules_df[['department_id_1', 'department_id_2', 'department_name_1', 'department_name_2', 'confidence', 'support']]
dept_rules_df.sort_values(by='department_id_1', ascending=False)
# Out:
#      department_id_1  department_id_2 department_name_1 department_name_2  \
# 115               21                4           missing           produce
# 131               21               13           missing            pantry
# 165               21               15           missing      canned goods
# 162               21               19           missing            snacks
# 161               21                3           missing            bakery
# ..               ...              ...               ...               ...
# 30                 1                3            frozen            bakery
# 32                 1                7            frozen         beverages
# 36                 1               15            frozen      canned goods
# 38                 1               16            frozen        dairy eggs
# 123                1                9            frozen   dry goods pasta
#
#      confidence   support
# 115    0.850281  0.044928
# 131    0.471225  0.024899
# 165    0.303765  0.016051
# 162    0.559354  0.029556
# 161    0.342709  0.018109
# ..          ...       ...
# 30     0.363416  0.141454
# 32     0.522939  0.203545
# 36     0.298741  0.116280
# 38     0.771534  0.300307
# 123    0.281510  0.109573
#
# [199 rows x 6 columns]

# %%
dept_rules_df.to_csv('departments_report.csv', index=False)

# %% [markdown]
# # Part B: Products report for each department

# %%
all_dept_rules = []
total_orders = len(order_df)
for dept_name in factors['department_name'].unique():
    dept_factors = factors[factors['department_name'] == dept_name]
    dept_orders = dept_factors.groupby('order_id')['product_id'].apply(list).reset_index(name='products')
    dept_orders = dept_orders[dept_orders['products'].apply(lambda x: len(set(x)) >= 2)]
    if dept_orders.empty:
        continue
        
    item_counts = Counter()
    pair_counts = Counter()

    for products in dept_orders['products']:
        unique_items = set(products)
        item_counts.update(unique_items)
        pair_counts.update(combinations(sorted(unique_items), 2))

    for (item1, item2), count_pair in pair_counts.items():
        support = count_pair / total_orders
        confidence_1_to_2 = count_pair / item_counts[item1]
        confidence_2_to_1 = count_pair / item_counts[item2]

        if support >= 0.003:
            if confidence_1_to_2 >= 0.25:
                all_dept_rules.append((dept_name, item1, item2, support, confidence_1_to_2))
            if confidence_2_to_1 >= 0.25:
                all_dept_rules.append((dept_name, item2, item1, support, confidence_2_to_1))

# %%
dept_rules_df = pd.DataFrame(all_dept_rules, columns=['department', 'product_id_1', 'product_id_2', 'confidence', 'support'])
dept_rules_df['product_name_1'] = dept_rules_df['product_id_1'].map(product_id_to_name)
dept_rules_df['product_name_2'] = dept_rules_df['product_id_2'].map(product_id_to_name)
dept_rules_df = dept_rules_df[['department', 'product_name_1', 'product_name_2', 'confidence', 'support']]
dept_rules_df.sort_values(['department', 'confidence'], ascending=[True, False])
# Out:
#    department                        product_name_1  \
# 51  beverages                  Lime Sparkling Water
# 2     produce                  Organic Strawberries
# 0     produce                  Organic Hass Avocado
# 17    produce                       Organic Avocado
# 32    produce                           Large Lemon
# 7     produce                          Strawberries
# 1     produce                   Organic Raspberries
# 21    produce                   Organic Raspberries
# 28    produce                                 Limes
# 26    produce                   Organic Blueberries
# 14    produce                      Organic Cucumber
# 4     produce                      Honeycrisp Apple
# 33    produce                    Organic Fuji Apple
# 22    produce                   Seedless Red Grapes
# 35    produce                         Yellow Onions
# 23    produce                         Organic Lemon
# 5     produce                      Organic Cilantro
# 39    produce  Organic Large Extra Fancy Fuji Apple
# 49    produce                        Broccoli Crown
# 18    produce                    Small Hass Avocado
# 10    produce                           Red Peppers
# 45    produce                   Organic Gala Apples
# 40    produce                        Cucumber Kirby
# 46    produce                  Organic Navel Orange
# 47    produce                  Organic Blackberries
# 9     produce              Apple Honeycrisp Organic
# 48    produce                          Organic Kiwi
# 19    produce            Organic Granny Smith Apple
# 12    produce     Organic Peeled Whole Baby Carrots
# 44    produce                Organic Tomato Cluster
# 15    produce     Organic Garnet Sweet Potato (Yam)
# 24    produce               Organic Red Bell Pepper
# 41    produce                 Organic D'Anjou Pears
# 6     produce                       Red Vine Tomato
# 8     produce                           Roma Tomato
# 36    produce                      Bunched Cilantro
# 29    produce                         Hass Avocados
# 37    produce                      Jalapeno Peppers
# 30    produce                      Organic Broccoli
# 38    produce                          Organic Kiwi
# 20    produce                   Organic Ginger Root
# 50    produce                    Orange Bell Pepper
# 42    produce                 Organic D'Anjou Pears
# 16    produce                      Bunched Cilantro
# 3     produce                      Clementines, Bag
# 11    produce                        Bartlett Pears
# 31    produce                  Organic Carrot Bunch
# 25    produce      Organic Lacinato (Dinosaur) Kale
# 27    produce                       Red Raspberries
# 13    produce                   Granny Smith Apples
# 43    produce            Grape White/Green Seedless
# 34    produce                    Yellow Bell Pepper
#
#                 product_name_2  confidence   support
# 51  Sparkling Water Grapefruit    0.003849  0.350451
# 2       Bag of Organic Bananas    0.023428  0.297321
# 0       Bag of Organic Bananas    0.018444  0.348201
# 17                      Banana    0.016889  0.314014
# 32                      Banana    0.016447  0.277057
# 7                       Banana    0.014847  0.323212
# 1       Bag of Organic Bananas    0.013566  0.336994
# 21        Organic Strawberries    0.012728  0.316168
# 28                 Large Lemon    0.012156  0.275237
# 26        Organic Strawberries    0.009672  0.270460
# 14      Bag of Organic Bananas    0.009664  0.279541
# 4                       Banana    0.009382  0.364417
# 33                      Banana    0.009222  0.397112
# 22                      Banana    0.008856  0.303315
# 35                      Banana    0.008163  0.295775
# 23      Bag of Organic Bananas    0.008132  0.316148
# 5                        Limes    0.007675  0.291125
# 39      Bag of Organic Bananas    0.007416  0.354205
# 49                      Banana    0.007050  0.325934
# 18                      Banana    0.006593  0.291148
# 10                      Banana    0.006387  0.293109
# 45      Bag of Organic Bananas    0.006173  0.300334
# 40                      Banana    0.005663  0.319707
# 46      Bag of Organic Bananas    0.005526  0.376623
# 47                      Banana    0.005259  0.252655
# 9       Bag of Organic Bananas    0.005236  0.320728
# 48      Bag of Organic Bananas    0.004984  0.355049
# 19      Bag of Organic Bananas    0.004954  0.287738
# 12                      Banana    0.004923  0.274660
# 44      Bag of Organic Bananas    0.004840  0.256773
# 15      Bag of Organic Bananas    0.004817  0.252195
# 24      Bag of Organic Bananas    0.004794  0.267318
# 41      Bag of Organic Bananas    0.004603  0.325606
# 6                       Banana    0.004527  0.274746
# 8                       Banana    0.004359  0.307197
# 36                       Limes    0.004253  0.299356
# 29      Bag of Organic Bananas    0.004222  0.272772
# 37                       Limes    0.004169  0.297768
# 30      Bag of Organic Bananas    0.004001  0.328536
# 38        Organic Strawberries    0.003940  0.280673
# 20      Bag of Organic Bananas    0.003712  0.250643
# 50                      Banana    0.003712  0.265685
# 42        Organic Strawberries    0.003643  0.257682
# 16                      Banana    0.003590  0.252682
# 3                       Banana    0.003552  0.354642
# 11                      Banana    0.003552  0.398631
# 31      Bag of Organic Bananas    0.003544  0.272887
# 25      Bag of Organic Bananas    0.003460  0.263341
# 27                      Banana    0.003346  0.304438
# 13                      Banana    0.003308  0.341195
# 43                      Banana    0.003064  0.275342
# 34          Orange Bell Pepper    0.003018  0.341379

# %%
dept_rules_df.to_csv('products_per_dept_report.csv', index=False)
